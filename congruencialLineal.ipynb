# %%
def congruencialineal(semilla, m, a, c,numerandom,cantidad):
    numerandom[0] = semilla
    for i in range(1, cantidad):
     numerandom[i] = ((numerandom[i - 1] * a) + c) % m
if __name__ == '__main__':
    semilla = 21
    m = 31
    a = 21
    c = 15
    cantidad = 100
    pseudoaleatorios = []

    numerandom = [0] * (cantidad)
 
    congruencialineal(semilla, m, a, c, numerandom, cantidad)
 
    for i in numerandom:
        print(" ")
        print(i, end = " ")
# Out:
#
# 21
# 22
# 12
# 19
# 11
# 29
# 4
# 6
# 17
# 0
# 15
# 20
# 1
# 5
# 27
# 24
# 23
# 2
# 26
# 3
# 16
# 10
# 8
# 28
# 14
# 30
# 25
# 13
# 9
# 18
# 21
# 22
# 12
# 19
# 11
# 29
# 4
# 6
# 17
# 0
# 15
# 20
# 1
# 5
# 27
# 24
# 23
# 2
# 26
# 3
# 16
# 10
# 8
# 28
# 14
# 30
# 25
# 13
# 9
# 18
# 21
# 22
# 12
# 19
# 11
# 29
# 4
# 6
# 17
# 0
# 15
# 20
# 1
# 5
# 27
# 24
# 23
# 2
# 26
# 3
# 16
# 10
# 8
# 28
# 14
# 30
# 25
# 13
# 9
# 18
# 21
# 22
# 12
# 19
# 11
# 29
# 4
# 6
# 17
# 0
